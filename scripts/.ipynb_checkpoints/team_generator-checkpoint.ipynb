# %%
import pandas as pd
import numpy as np

# %%
team_data = pd.read_csv("../assets/team_24_25.csv")

team_dict = team_data.T.to_dict()

# %%
print(team_dict)
# Out:
# {0: {'Timestamp': '7/2/2023 19:56:23', 'Name': 'Yash Rampuria', 'Email': 'yashrampuria007@gmail.com', 'LinkedIn': 'https://www.linkedin.com/in/yash-rampuria-5ba350226', 'Facebook': nan, 'Your Description': 'I am a thirdie in the mech dept and the Perception head in the IITB Racing team. Love filmmaking amd videography and open to making cinematic videos of literally anything!', 'Display Image': 'https://drive.google.com/open?id=11hwCmJvYRAei4C4jebz7USByyVjAtsw4', 'Institute Councils': 'Technical Affairs Council', 'Independent Bodies/Cells/Fests': 'E-Cell, Mood Indigo', 'Technical Teams + Clubs': 'AUV, IITB-Racing', 'Cultural Activities': 'Film and Media', 'Sports Teams + Clubs': nan, 'Interests': 'Data Science, Core, Research'}, 1: {'Timestamp': '7/2/2023 20:02:23', 'Name': 'Gehna Gudhainia', 'Email': 'gehnagudhainia@gmail.com', 'LinkedIn': 'https://www.linkedin.com/in/gehna-gudhainia-992418223', 'Facebook': 'https://www.facebook.com/gehna.gudhainia.25?mibextid=LQQJ4d', 'Your Description': " Hey there, I'm Gehna, hailing from Jaipur! When it comes to making a splash, swimming is my ultimate go-to, keeping me afloat with waves of excitement. But let me tell you, nothing beats the thrill of diving into fascinating conversations and connecting with amazing folks like you. If you're up for a stroll, count me in! I'm always game for some ‘sole’-searching adventures. Oh, and books? They're my latest page-turning obsession. As an internship coordinator, I get to sprinkle some professional magic. And when it's time to unwind, I'm all ears for music's sweet symphony! ", 'Display Image': 'https://drive.google.com/open?id=1LwxMN3kH3RXKLq6ATzRUtzsZSEgkx4VH', 'Institute Councils': nan, 'Independent Bodies/Cells/Fests': 'Abhyuday, E-Cell, IIT BBC, Placement Cell', 'Technical Teams + Clubs': nan, 'Cultural Activities': nan, 'Sports Teams + Clubs': 'Aquatics', 'Interests': 'Finance, Case Competitions, Communication, Marketing, Business'}, 2: {'Timestamp': '7/2/2023 20:23:35', 'Name': 'Mokshit Naidu', 'Email': 'mokshit.n@gmail.com', 'LinkedIn': 'https://www.linkedin.com/in/mokshitnaidu/', 'Facebook': nan, 'Your Description': 'A Bengalurean in almost all ways (but still don’t know Kannada); love to talk, but intimidated by all social situations (I like to live my life in paradoxes)!', 'Display Image': 'https://drive.google.com/open?id=17AZ_3YToAgdWNtyG_1JbpYI5VvWIPcPi', 'Institute Councils': nan, 'Independent Bodies/Cells/Fests': nan, 'Technical Teams + Clubs': 'IITB-Racing', 'Cultural Activities': nan, 'Sports Teams + Clubs': 'Athletics, Football', 'Interests': 'Finance, Case Competitions, Communication, Marketing, Business'}, 3: {'Timestamp': '7/2/2023 20:26:38', 'Name': 'Ruchir Parekh', 'Email': 'ruchir.m.parekh@gmail.com', 'LinkedIn': 'https://www.linkedin.com/in/ruchir-mital-parekh-52b550228/', 'Facebook': nan, 'Your Description': "Hi, I'm Ruchir(spelt Ruchir). Love to read books and cycle.", 'Display Image': 'https://drive.google.com/open?id=1d_e_h-Qiinon4c3nIwb5rEhV5q8sBD58', 'Institute Councils': 'Academic Affairs Council', 'Independent Bodies/Cells/Fests': nan, 'Technical Teams + Clubs': nan, 'Cultural Activities': 'Speaking Arts/Stand Up', 'Sports Teams + Clubs': nan, 'Interests': 'Finance, Case Competitions, Business'}, 4: {'Timestamp': '7/2/2023 20:26:41', 'Name': 'Ayush Agarwal', 'Email': 'ayush200903@gmail.com', 'LinkedIn': 'https://in.linkedin.com/in/ayush-agarwal-9b33a3237', 'Facebook': nan, 'Your Description': "I am currently an Editor at Insight and was a Business Team Member of the DAV team in my second year. I love reading, watching films and playing the piano. I also play football and badminton whenever I get a chance. I'm interested in the non-core sector but am open to exploring other fields as well!", 'Display Image': 'https://drive.google.com/open?id=1dOLe8gRsz2uAjTPYymSO4bQ6ycdDHqON', 'Institute Councils': nan, 'Independent Bodies/Cells/Fests': 'Insight, TechFest', 'Technical Teams + Clubs': nan, 'Cultural Activities': ...

# %%
import jinja2

subs = jinja2.Environment( 
              loader=jinja2.FileSystemLoader('./')      
              ).get_template('profile.html').render(team=team_dict)
# lets write the substitution to a file
with open('test.html','w', encoding="utf-8") as f: f.write(subs)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[5], line 7
#       3 subs = jinja2.Environment(
#       4               loader=jinja2.FileSystemLoader('./')
#       5               ).get_template('profile.html').render(team=team_dict)
#       6 # lets write the substitution to a file
# ----> 7 with open('test.html','w') as f: f.write(subs)
#
# File C:\ProgramData\anaconda3\lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 20767-20768: character maps to <undefined>
